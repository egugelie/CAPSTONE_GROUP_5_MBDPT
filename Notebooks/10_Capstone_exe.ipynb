# %%
pip install OpenAI
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.6 MB/s eta 0:00:00
# ...

# %%
pip install gtts

# %%
from google.colab import drive
import random
import sys

# Mount Google Drive
drive.mount('/content/drive')

# Add the path to the scripts
script_path = '/content/drive/Shared drives/Capstone/Notebooks/Scripts/'
sys.path.append(script_path)

# Verify the path has been added correctly
print("Current sys.path:", sys.path)

# Check if the files exist in the directory
# !ls '/content/drive/Shared drives/Capstone/Notebooks/Scripts/'
# Out:
# Mounted at /content/drive
# Current sys.path: ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/Shared drives/Capstone/Notebooks/Scripts/']
# capstone_capgemini.py		       ranking_script.py
# cluster_rank_recommendation.py	       recommend_aisle.py
# General_Apriori_script.py	       recommend_cluster.py
# load_data_cosine_similarity_script.py  recommender_cosine_similarity_script.py
# predict_cluster.py		       voice_recommend_aisle.py
# __pycache__			       voice_recommender_cosine_similarity_script.py

# %%
from capstone_capgemini import tech_experience
from capstone_capgemini import user_experience
from capstone_capgemini import random_articles

# %%
user_experience()

# %%
tech_experience()

# %%
random_articles(10)
# Out:
# Random articles as a guide:
# - PENNE RIGATE ORGÁNICA
# - LAS FRESAS ENTERAS
# - SALSA DE MANZANA
# - PURE & NATURAL CREMA AGRIA
# - YOBABY MELOCOTÓN PERA YOGUR
# - FAVORITOS TRADICIONALES DE TOMATE Y ALBAHACA PASTA SAUCE
# - LIMONADA
# - SIN GRASA YOGUR DE ARÁNDANO
# - PEPINO ORGÁNICA
# - ORGÁNICAS GRANDES GRADO AA HUEVOS OMEGA-3
