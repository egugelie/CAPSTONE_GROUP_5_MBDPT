# %%
import os
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)

# Path to the CSV file
route = '/content/drive/Shared drives/Capstone/Dataset_cleaned_merged/df_final_version.csv'
destination = '/content/drive/Shared drives/Capstone/Dataset_cleaned_merged/Cluster_models/'

# Read the CSV file into a DataFrame
df = pd.read_csv(route)

# Select and process product information
pruduct_info = df[['id_producto', 'nombre_producto', 'id_pasillo', 'id_departamento', 'pasillo', 'departamento']]
pruduct_info = pruduct_info.drop_duplicates(subset=['id_producto'])
pruduct_info = pruduct_info.set_index('id_producto')

# Save the DataFrame to a CSV file
pruduct_info.to_csv(os.path.join(destination, 'pruduct_info_clustering.csv'))

print("CSV file saved successfully.")
# Out:
# Mounted at /content/drive
# CSV file saved successfully.

# %%
pruduct_info
# Out:
#                                                nombre_producto  id_pasillo  \
# id_producto
# 49302                                     EL YOGUR DE BULGARIA       120.0
# 11109        4% ORGÁNICO QUESO GRASA DE LECHE LECHE ENTERA ...       108.0
# 10246                              CORAZONES DE APIO ORGÁNICOS        83.0
# 49683                                             KIRBY PEPINO        83.0
# 43633        LAS SARDINAS LIGERAMENTE AHUMADO EN ACEITE DE ...        95.0
# ...                                                        ...         ...
# 25275                   SWEET & ORIGINAL GRUESO SALSA BARBACOA         5.0
# 1528                                        ROCÍA DECORACIONES        97.0
# 47935                   ORIGINAL CLASSIC BÁLSAMO LABIAL SPF 12        73.0
# 9491                               LECHE DE CABRA Y JABÓN CHAI        25.0
# 38900                    PLANICIE DORADA TOSTADAS MIGAS DE PAN         5.0
#
#              id_departamento                                pasillo  \
# id_producto
# 49302                   16.0                                  YOGUR
# 11109                   16.0                    OTROS QUESOS CREMAS
# 10246                    4.0                      VEGETALES FRESCOS
# 49683                    4.0                      VEGETALES FRESCOS
# 43633                   15.0                MARISCOS CARNE ENLATADA
# ...                      ...                                    ...
# 25275                   13.0      PREPARACIÓN DE LA CARNE MARINADOS
# 1528                    13.0  SUMINISTROS PARA HORNEAR Y DECORACIÓN
# 47935                   11.0                         CUIDADO FACIAL
# 9491                    11.0                                  JABÓN
# 38900                   13.0      PREPARACIÓN DE LA CARNE MARINADOS
#
#                     departamento
# id_producto
# 49302           HUEVOS Y LÁCTEOS
# 11109           HUEVOS Y LÁCTEOS
# 10246          FRUTAS Y VERDURAS
# 49683          FRUTAS Y VERDURAS
# 43633        PRODUCTOS ENLATADOS
# ...                          ...
# 25275                   DESPENSA
# 1528                    DESPENSA
# 47935           CUIDADO PERSONAL
# 9491            CUIDADO PERSONAL
# 38900                   DESPENSA
#
# [38403 rows x 5 columns]
